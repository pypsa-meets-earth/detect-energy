# %% [markdown]
# *   [Huge List of Data Labeling Tools](https://github.com/heartexlabs/awesome-data-labeling)
# *   [CVAT](https://github.com/openvinotoolkit/cvat): Most widely used
# *   [labelimg](https://github.com/tzutalin/labelImg): pyqt based
# *   [MakeSense](https://github.com/SkalskiP/make-sense): Super-quick web-based solution
# *   [Label Studio](https://github.com/heartexlabs/label-studio): Works with many different types of data types
# *   [Label Images Directly on Colab](https://ricardodeazambuja.com/deep_learning/2020/04/09/colab-utils/): Interesting
# *   [Oxford VGG](https://www.robots.ox.ac.uk/~vgg/software/via/)

# %% [markdown]
# # Label-Studio

# %% [markdown]
# ## Install

# %%
# !pip install label-studio
# Out:
# ...
#      |████████████████████████████████| 47.2 MB 2.1 MB/s
# ...
#      |████████████████████████████████| 199 kB 57.8 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 30.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 54.3 MB/s
# ...
#      |████████████████████████████████| 3.4 MB 49.2 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 171 kB 67.0 MB/s
# ...
#      |████████████████████████████████| 7.8 MB 43.9 MB/s
# ...
#      |████████████████████████████████| 356 kB 72.6 MB/s
# ...
#      |████████████████████████████████| 80 kB 9.6 MB/s
# ...
#      |████████████████████████████████| 73 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 68 kB 8.2 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 73.1 MB/s
# ...
#      |████████████████████████████████| 7.0 MB 55.5 MB/s
# ...
#      |████████████████████████████████| 45 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 227 kB 60.5 MB/s
# ...
#      |████████████████████████████████| 56 kB 5.0 MB/s
# ...

# %%
# !npm install -g localtunnel
# Out:
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/lt.js
# + localtunnel@2.0.2
# added 22 packages from 22 contributors in 1.452s

# %% [markdown]
# ## Tunnel

# %%
# %env LABEL_STUDIO_LOCAL_FILES_SERVING_ENABLED=true
# Out:
# env: LABEL_STUDIO_LOCAL_FILES_SERVING_ENABLED=true

# %%
# !nohup label-studio start --port 8050 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# !lt --port 8050
# Out:
# your url is: https://smart-newt-70.loca.lt

# %% [markdown]
# # Make-Sense

# %% [markdown]
# ## Install

# %%
# !git clone https://github.com/SkalskiP/make-sense.git
# Out:
# Cloning into 'make-sense'...
# remote: Enumerating objects: 5380, done.
# remote: Counting objects: 100% (1117/1117), done.
# remote: Compressing objects: 100% (285/285), done.
# remote: Total 5380 (delta 919), reused 899 (delta 827), pack-reused 4263
# Receiving objects: 100% (5380/5380), 182.22 MiB | 34.14 MiB/s, done.
# Resolving deltas: 100% (3504/3504), done.

# %%
# %cd make-sense
# Out:
# /content/make-sense

# %%
# !npm install
# Out:
# > @tensorflow/tfjs-node@3.9.0 install /content/make-sense/node_modules/@tensorflow/tfjs-node
# > node scripts/install.js
#
# CPU-linux-3.9.0.tar.gz
# * Downloading libtensorflow
# https://storage.googleapis.com/tensorflow/libtensorflow/libtensorflow-cpu-linux-x86_64-2.5.0.tar.gz
# ...

# %% [markdown]
# ## Tunnel

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8050)"))
# Out:
# https://7o4p3azoqdy-496ff2e9c6d22116-8050-colab.googleusercontent.com/

# %%
# !npm start
# Out:
# > make-sense@1.0.0 start /content/make-sense
# > react-scripts start
#
# ℹ ｢wds｣: Project is running at http://172.28.0.2/
# ℹ ｢wds｣: webpack output is served from
# ℹ ｢wds｣: Content not from webpack is served from /content/make-sense/public
# ℹ ｢wds｣: 404s will fallback to /
# Starting the development server...
#
# ...
#
# WARNING: You are currently running a version of TypeScript which is not officially supported by @typescript-eslint/typescript-estree.
#
# You may find that it works just fine, or you may not.
#
# SUPPORTED TYPESCRIPT VERSIONS: >=3.3.1 <4.4.0
#
# YOUR TYPESCRIPT VERSION: 4.4.2
#
# Please only submit bug reports when using the officially supported version.
#
# ...
# Compiled successfully!
#
# You can now view make-sense in the browser.
#
#   Local:            http://localhost:3000
#   On Your Network:  http://172.28.0.2:3000
#
# Note that the development build is not optimized.
# To create a production build, use npm run build.
